# %%
from micrograd.engine.value import Value
from micrograd.nn.mlp import MLP
from micrograd.utils.visualization import draw_dot
from micrograd.examples.moons_classification import train_moons_classifier

# Exemple simple d'utilisation de Value
a = Value(3.0)
b = Value(2.0)
c = a * b + b
c.backward()
print(f"a.grad = {a.grad}, b.grad = {b.grad}")

# Visualise le graphe de calcul
dot = draw_dot(c)
dot.render('example_graph', format='png', cleanup=True)

# exemple de classification
model = train_moons_classifier()
# Out:
# a.grad = 2.0, b.grad = 4.0
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\Victor\AppData\Local\Programs\Python\Python313\Lib\site-packages\graphviz\backend\execute.py:78, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      77     else:
# ---> 78         proc = subprocess.run(cmd, **kwargs)
#      79 except OSError as e:
#
# File c:\Users\Victor\AppData\Local\Programs\Python\Python313\Lib\subprocess.py:554, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     552     kwargs['stderr'] = PIPE
# --> 554 with Popen(*popenargs, **kwargs) as process:
#     555     try:
#
# ...
